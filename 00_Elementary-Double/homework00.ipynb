# %% [markdown]
# #### Задача 1 (*) - логика.
#
# Программа получает на вход данные пользователя: логин, возраст и пароль. Она должна проверить, есть ли пользователю 18 лет. Если нет, она должна выдать сообщение "Ограничение по возрасту, пользователь не зарегистрирован" и закончить работу. В ином случае она должна проверить, не совпадает ли пароль с логином. Если совпадает, пусть программа выдаст сообщение "Совпадение логина и пароля, пользователь не зарегистрирован" и закончит работу. Если же оба условия выполнены, должно быть выдано сообщение вида "Пользователь <логин> зарегистрирован успешно". Затем пусть программа запросит данные для входа: логин и пароль. Если они совпадают с введенными ранее, пользователь должен получить сообщение "Здравствуйте, <логин>!"
#
# **Примечание:** Если вы опытные программисты, проверку для регистрации можете написать в виде отдельной функции, это удобно.

# %%
# your code here

# %% [markdown]
# #### Задача 2 (*) - строки.
#
# Вводится строка из символов русского языка, среди которых могут быть буквы и служебные символы (гарантируется, что цифр не будет). Разделите строку на слова по пробелам, затем посчитайте среднее количество букв и слогов для этих слов. Конечно, при подсчете количества букв служебные символы, если они есть, нужно отбрасывать. Однако при подсчете количества слогов учитывайте, не было ли внутри слова дефиса. Если дефис внутри слова есть и стоит между двумя одинаковыми гласными, то считайте эти гласные за один слог, а не за два.
#
# **Пример**: "лилии" - три слога; но "Лили-и" - два слога.

# %%
# your code here

# %% [markdown]
# #### Задача 3 (*) - строки продолжение.
#
# Дополните код из предыдущего задания - выдайте о введенной строке информацию по ее пунктуации: сколько в ней предложений и правильно ли они оформлены знаками препинания. Для простоты перед проверкой замените все встречающиеся в предложении восклицательные и вопросительные знаки точками, а также удалите все кавычки и апострофы.
#
# Мы будем считать, что предложением является любая последовательность символов, начинающаяся с начала строки либо с символа после точки и заканчивающаяся точкой либо концом строки. Правильным оформлением для нас будет такое, чтобы:
#
# - когда предложение начинается не с начала строки, его первым символом всегда был пробел;
#
# - первый символ в предложении, отличный от пробела, всегда был заглавной буквой;
#
# - когда предложение заканчивается концом строки, его последним символом, отличным от пробела, была буква;
#
# - когда предложение не заканчивается концом строки, его предпоследним символом была буква;
#
# - когда внутри предложения встречается запятая, после нее всегда был пробел;
#
# - перед и после дефиса не болжно быть пробелов;
#
# - внутри предложения не должно быть других служебных символов, кроме запятых и дефисов.
#
# **Примечание:** Это и предыдущее задание - пример очень примитивной токенизации. Как лингвистам вам доведется часто этим заниматься, но, к счастью, сейчас существуют библиотеки для лингвистов, в которых эти задачи решаются гораздо лучше, удобнее и правильнее. Я дала вам эти задания, чтобы вы почувствовали, что у этих библиотек делается "под капотом".

# %%
# your code here

# %% [markdown]
# #### Задача 4 (*) - списки.
#
# Пользователь вводит список целых чисел (через пробел) и целевое число, тоже целое. Программа должна проходить по списку с начала и возвращать пары индексов таких чисел из списка, которые в сумме дают целевое число. Если таких пар больше одной, функция должна возвращать индексы только для различных пар.
#
# **Пример**:
#
#
# *Ввод:*
#
#
# (список чисел) 5 17 23 1 5 19
#
#
# (целевое число) 24
#
#
# *Вывод:*
#
# 0, 5
#
#
# 2, 3
#
# (ВНИМАНИЕ! Пары 4, 5 в правильной выдаче по этим данным быть не должно.)
#
#
# **Примечание:** Можете исключать повторы через множества или как вам больше нравится.

# %%
# your code here

# %% [markdown]
# #### Задача 5 (**) - вложенные циклы.
# Напишите программу, которая будет просить у пользователя ввести последовательность целых чисел (через пробел), а затем проверять, являются ли эти числа степенями одного и того же числа. Если такое число найдено, пусть программа выдаст его, если же нет, пусть выдаст сообщение "Основание не найдено" и повторит запрос. Пусть программа работает до тех пор, пока пользователь не введет такую последовательность, для которой найдется основание.
#
# **Пример**:
#
#
# *Ввод:*
#
#
# 1 2 3 4
#
#
# *Вывод:*
#
#
# Основание не найдено
#
#
# *Ввод:*
#
#
# 1 2 4 8
#
#
# *Вывод:*
#
#
# 2
#
#
# *Конец выполнения программы*
#
# **Примечание**: Для проверки основания можете использовать встроенную функцию log модуля math, если знаете, как это делается. Но будьте внимательны, поскольку при работе с логарифмами могут быть ошибки арифметики чисел с плавающей точкой.

# %%
# your code here
