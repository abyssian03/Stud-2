# %% [markdown]
# #### Задача 1.
#
# С помощью модуля math выведите на экран число π, посчитайте количество знаков после занятой, с точностью до которого эта константа хранится в питоне, и напечатайте результат. Считайте знаки программно, а не вручную.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# С помощью модуля math создайте переменную infinity, равную математической бесконечности. Затем создайте цикл со счетчиком, который будет продолжаться до тех пор, пока значение счетчика будет меньше infinity (то есть бесконечно). Внутри цикла поместите input() и задайте условие, что если пользователь ввел 'exit', программа должна выходить из цикла по break().

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# Протестируйте еще один способ создания бесконечного цикла. С помощью функции count() модуля itertools создайте бесконечную последовательности целых чисел. Печатайте элементы этой последовательности один за другим, в столбик, и после каждого запрашивайте ввод у пользователя. Как и раньше, пусть программа выходит из цикла по  break(), если пользователь ввел 'exit'.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# Дополните код из предыдущего задания: пусть программа выходит после слова 'exit' не по break, a по команде exit(0) из модуля sys.

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# С помощью модуля os создайте в папке скрипта новую подпапку, назовите ее example. Выведите содержимое папки скрипта на экран.
#
# **Примечание:** Папка скрипта - это папка, которая открывается по умолчанию, т.е. если в адресе до имени файла или папки, с которой вы работаете, ничего не написано.

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# Дополните код предыдущего задания: перейдите вашу в папку example и создайте внутри нее новую папку example_inter. Затем переименуйте папку example в example_outer и выведите на экран ее содержимое. Затем удалите все, что вы создали, и снова выведите содержимое папки скрипта на экран.
#
# **Подсказка:** Вам может пригодиться команда chdir(".."), относящаяся к модулю os и выполняющая переход на один уровень вверх по дереву каталогов, т.е. из дочерней папки в родительскую.

# %%
# your code here

# %% [markdown]
# #### Задача 7 (*) - последняя звезда.
#
# Найдите информацию по модулю sys и выясните, как вызвать словарь уже подключенных к скрипту модулей. Выведите этот словарь на экран. Погуглите назначение нескольких (хотя бы трех) модулей из словаря и напишите в комментариях, что вы нашли.

# %%
# your code here
