# %% [markdown]
# #### Задача 1.
#
# Возьмите код какой-нибудь из прошлых задач, которую вы решали. С помощью модуля time измерьте время работы этого кода и выведите его на экран.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Нарисуйте прогресс-бар из десяти символов # с помощью print() с параметром end и модуля time. Пусть новый символ появляется на экране каждую секунду. По окончании отрисовки прогресс-бара пусть печатается с новой строки "Успешно!".

# %%
# your code here

# %% [markdown]
# #### Задача 3.
#
# С помощью модуля datetime выведите текущую дату и дату, которая наступит по истечении *n* дней. Число *n* вводится пользователем.

# %%
# your code here

# %% [markdown]
# #### Задача 4.
#
# С помощью модуля datetime создайте таймер, который можно установить на заданное время, и он будет показывать обратный отсчет (с точностью до секунд).

# %%
# your code here

# %% [markdown]
# #### Задача 5.
#
# С помощью модуля random выберите случайное число от 1 до 10 (не выводите его, а просто запишите в переменную). Затем предложите пользователю угадать с трех раз, что это за число. Если он не угадает с первой попытки, напишите "больше" или "меньше" в зависимости от того, какое число загадано. Если он не угадает со второго раза, снова напишите ему подсказку и как-нибудь подбодрите его. В случае выигрыша поздавьте его, а в случае проигрыша предложите сыграть еще раз.

# %%
# your code here

# %% [markdown]
# #### Задача 6.
#
# С помощью модуля random создайте программу, которая будет выбирать случайную карту из 36-карточной колоды и выводить на экран сообщение вида: "Вам выпала карта <номинал или название> <масть>"

# %%
# your code here

# %% [markdown]
# #### Задача 7 (*) - на самостоятельность.
#
# Разберитесь, как работает модуль itertools. С его помощью решите следующую задачу: нужно подсчитать число способов, которыми *n* писем можно разложить по *m* ящикам. Числа *n* и *m* вводятся пользователем. Гарантируется, что *n* не превышает *m*.

# %%
# your code here

# %% [markdown]
# #### Задача 8 (**) - математика и рекурсия
#
# С помощью модуля math посчитайте факториал какого-нибудь большого числа. Затем с помощью модуля sys установите максимальную глубину рекурсии меньше того числа, факториал которого вы считали. Запустите подсчет факториала снова. Посмотрите, что будет.

# %%
# your code here
